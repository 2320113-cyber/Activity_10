# %%
# Library imports
# !pip install sympy control matplotlib numpy

import sympy as sp
from control import tf, step_response, poles, zeros, pzmap
import matplotlib.pyplot as plt
import numpy as np

# %%
#ALL symbols
s, S, X, Y = sp.symbols('s S X Y')
sp.init_printing()

print("✅ Symbols defined:")
print(f"  s = {s}")
print(f"  S = {S}")
print(f"  X = {X}, Y = {Y}")
# Out:
# ✅ Symbols defined:
#   s = s
#   S = S
#   X = X, Y = Y

# %%
import sympy as sp
s, S = sp.symbols('s S') 

# Coefficients only (no X,Y)
A_coeff = 2*S**2 + s      # 2S² + s
B_coeff = s + 1           # s + 1

sp.pprint(sp.simplify(B_coeff / A_coeff))
# Out:
#  s + 1
# ────────
#    2
# 2⋅S  + s

# %%
from control import tf, poles, zeros

# Direct coefficients (no sympy needed!)
num_coeffs = [1, 1]   # s + 1
den_coeffs = [1, 2]   # s + 2

sys = tf(num_coeffs, den_coeffs)
print(sys)
print(f"Poles: {poles(sys)}")
print(f"Zeros: {zeros(sys)}")
# Out:
# <TransferFunction>: sys[5]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#   s + 1
#   -----
#   s + 2
# Poles: [-2.+0.j]
# Zeros: [-1.+0.j]

# %%
import control as ctrl
import matplotlib.pyplot as plt

# NEW TRANSFER FUNCTION for gain=25
G = ctrl.tf([25, 25], [1, 2])  # 25(s+1)/(s+2) → Steady-state=25

# Your exact code:
t, y = ctrl.step_response(G)
plt.figure()   
plt.plot(t, y)
plt.title('Step Response')
plt.xlabel('Time (s)')
plt.ylabel('Output')
plt.grid()
plt.show()

# %%
sys = ctrl.tf([25, 25], [1, 2])  # Your step response system
plt.figure(figsize=(8, 6))
ctrl.pzmap(sys, grid=True)
plt.title('Pole-Zero Map')
plt.show()
